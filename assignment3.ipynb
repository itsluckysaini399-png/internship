# %% [markdown]
# 1. Create a class named Student with attributes:
# o name
# o age
# o course
# Create an object and print all the details

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course
        
student1 = Student("Lucky saini", 21, "Computer Science")
print(f"Name: {student1.name}")
print(f"Age: {student1.age}")
print(f"Course: {student1.course}")
# Out:
# Name: Lucky saini
# Age: 21
# Course: Computer Science

# %% [markdown]
# 2. Create a class named Car with attributes:
# o brand
# o model
# o price
# Create two objects and display their details.

# %%
class Car:
    def __init__(self, brand, model, price):
        self.brand = brand
        self.model = model
        self.price = price
        
car1 = Car("Toyota", "Camry", 24000)
car2 = Car("Honda", "Civic", 22000)
print(f"Car 1 - Brand: {car1.brand}, Model: {car1.model}, Price: ${car1.price}")
print(f"Car 2 - Brand: {car2.brand}, Model: {car2.model}, Price: ${car2.price}")
# Out:
# Car 1 - Brand: Toyota, Model: Camry, Price: $24000
# Car 2 - Brand: Honda, Model: Civic, Price: $22000

# %% [markdown]
# 3. Create a class named Employee and use a constructor (__init__) to
# initialize:
# o employee_id
# o name
# o salary
# Print the employee details

# %%
class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary
employee1 = Employee(101, "Lucky saini", 50000)
print(f"Employee ID: {employee1.employee_id}")
print(f"Name: {employee1.name}")
print(f"Salary: ${employee1.salary}")
# Out:
# Employee ID: 101
# Name: Lucky saini
# Salary: $50000

# %% [markdown]
# 4. Create a class named Rectangle with attributes:
# o length
# o width
# Create a method to calculate and print the area of the rectangle.

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width
        
    def area(self):
        return self.length * self.width
rectangle1 = Rectangle(5, 3)
print(f"Area of the rectangle: {rectangle1.area()}")
# Out:
# Area of the rectangle: 15

# %% [markdown]
# 5. Create a class named Circle with an attribute radius.
# Create a method that calculates and prints the area of the circle

# %%
import math
class Circle:
    def __init__(self, radius):
        self.radius = radius
        
    def area(self):
        return math.pi * (self.radius ** 2)
circle1 = Circle(4)
print(f"Area of the circle: {circle1.area()}")
# Out:
# Area of the circle: 50.26548245743669

# %% [markdown]
# 6. Create a class named BankAccount with:
# o account_holder
# o balance
# Create methods:
# o deposit(amount)
# o withdraw(amount)
# Display the updated balance after each transaction

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance
        
    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited ${amount}. Updated balance: ${self.balance}")
        
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"Withdrew ${amount}. Updated balance: ${self.balance}")
account1 = BankAccount("Lucky saini", 1000)
account1.deposit(500)
account1.withdraw(200)
account1.withdraw(1500)
# Out:
# Deposited $500. Updated balance: $1500
# Withdrew $200. Updated balance: $1300
# Insufficient funds

# %% [markdown]
# 7. Create a class named Animal with a method sound().
# Create a child class Dog that overrides the sound() method and prints
# "Bark".

# %%
class Animal:
    def sound(self):
        pass
class Dog(Animal):
    def sound(self):
        print("Bark")
dog1 = Dog()
dog1.sound()
# Out:
# Bark

# %% [markdown]
# 8. Create a class named Person with attributes:
# o name
# o age
# Create a child class Student with an additional attribute:
# o roll_number
# Display all the details using an object of the Student class.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
class Student(Person):
    def __init__(self, name, age, roll_number):
        super().__init__(name, age)
        self.roll_number = roll_number
student1 = Student("Lucky saini", 21, "CS043")
print(f"Name: {student1.name}")
print(f"Age: {student1.age}")
print(f"Roll Number: {student1.roll_number}")
# Out:
# Name: Lucky saini
# Age: 21
# Roll Number: CS043

# %% [markdown]
# 9. Create a class named Calculator with methods:
# o add()
# o subtract()
# o multiply()
# o divide()
# Take two numbers as input and perform all operations

# %%
class Calculator:
    def add(self, a, b):
        return a + b
    
    def subtract(self, a, b):
        return a - b
    
    def multiply(self, a, b):
        return a * b
    
    def divide(self, a, b):
        if b == 0:
            return "Cannot divide by zero"
        return a / b
calculator = Calculator()
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print(f"Addition: {calculator.add(num1, num2)}")
print(f"Subtraction: {calculator.subtract(num1, num2)}")
print(f"Multiplication: {calculator.multiply(num1, num2)}")
print(f"Division: {calculator.divide(num1, num2)}")
# Out:
# Addition: 15.0
# Subtraction: -5.0
# Multiplication: 50.0
# Division: 0.5

# %% [markdown]
# 10.Create a class named LibraryBook with attributes:
# ● book_name
# ● author
# ● price
# Create a method display_book_info() that prints all book details. Create
# at least three book objects and display their information.

# %%
class LibraryBook:
    def __init__(self, book_name, author, price):
        self.book_name = book_name
        self.author = author
        self.price = price
        
    def display_book_info(self):
        print(f"Book Name: {self.book_name}")
        print(f"Author: {self.author}")
        print(f"Price: ${self.price}")
book1 = LibraryBook("python", "Manas", 10.99)
book2 = LibraryBook("java", "mohit", 8.99)
book3 = LibraryBook("journey with Lucky", "Lucky Saini", 9.99)
book1.display_book_info()
print()
book2.display_book_info()
print()
book3.display_book_info()
# Out:
# Book Name: python
# Author: Manas
# Price: $10.99
#
# Book Name: java
# Author: mohit
# Price: $8.99
#
# Book Name: journey with Lucky
# Author: Lucky Saini
# Price: $9.99
